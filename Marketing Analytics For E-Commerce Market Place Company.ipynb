# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
customers = pd.read_csv('CUSTOMERS.csv')
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix customer_city  customer_state
# ...

# %%
sellers = pd.read_csv('SELLERS.csv')
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13023
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#           seller_city    seller_state
# 0               Alwal  Andhra Pradesh
# 1               Alwal  Andhra Pradesh
# 2           Badepalle  Andhra Pradesh
# 3        Akkarampalle  Andhra Pradesh
# ...

# %%
products = pd.read_csv('PRODUCTS.csv')
products
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  Perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        Art
# 2      96bd76ec8810374ed1b65e291975717f             Sports_Leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       Baby
# 4      9dc1a7de274444849c219cff195d0b71                 Housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            Furniture_Decor
# 32947  bf4538d88321d0fd4412a93c974510e6  Construction_Tools_Lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             Bed_Bath_Table
# 32949  83808703fc0706a22e264b9d75f04a2e      Computers_Accessories
# 32950  106392145fca363410d287a815be6de4             Bed_Bath_Table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
orders = pd.read_csv('ORDERS.csv')
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
order_items = pd.read_csv('ORDER_ITEMS.csv')
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_payments = pd.read_csv('ORDER_PAYMENTS.csv')
order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1          UPI
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1          UPI
#
#         payment_installments  payment_value
# ...

# %%
order_review_ratings = pd.read_csv('ORDER_REVIEW_RATINGS.csv')
order_review_ratings
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# ...

# %%
geolocation = pd.read_csv('GEO_LOCATION.csv')
geolocation
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                             1037       -23.545621       -46.639292
# 1                             1046       -23.546081       -46.644820
# 2                             1041       -23.544392       -46.639499
# 3                             1035       -23.541578       -46.641607
# 4                             1012       -23.547762       -46.635361
# ...                            ...              ...              ...
# 19010                        99955       -28.107588       -52.144019
# 19011                        99970       -28.345143       -51.876926
# 19012                        99910       -27.863500       -52.084760
# 19013                        99920       -27.858716       -52.300403
# 19014                        99952       -28.160371       -51.936922
#
#       geolocation_city geolocation_state
# 0         Akkarampalle    Andhra Pradesh
# 1         Akkarampalle    Andhra Pradesh
# ...

# %%
print('CUSOMER :')
print(customers.isnull().sum())
print('-'*125)

print('SELLER :')
print(sellers.isnull().sum())
print('-'*125)

print('PRODUCTS :')
print(products.isnull().sum())
print('-'*125)

print('ORDERS :')
print(orders.isnull().sum())
print('-'*125)

print('ORDER_ITEMS :' )
print(order_items.isnull().sum())
print('-'*125)

print('ORDER_PAYMENTS :' )
print(order_payments.isnull().sum())
print('-'*125)

print('ORDER_REVIEW_RATINGS :')
print(order_review_ratings.isnull().sum())
print('-'*125)

print('GEOLOCATION :')
print(geolocation.isnull().sum())
# Out:
# CUSOMER :
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
# SELLER :
# seller_id                  0
# seller_zip_code_prefix     0
# seller_city               57
# seller_state              57
# dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
# PRODUCTS :
# product_id                      0
# product_category_name         623
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# ...

# %%
print('CUSOMER :')
print(customers.dtypes)
print('-'*125)

print('SELLER :')
print(sellers.dtypes)
print('-'*125)

print('PRODUCTS :')
print(products.dtypes)
print('-'*125)

print('ORDERS :')
print(orders.dtypes)
print('-'*125)

print('ORDER_ITEMS :' )
print(order_items.dtypes)
print('-'*125)

print('ORDER_PAYMENTS :' )
print(order_payments.dtypes)
print('-'*125)

print('ORDER_REVIEW_RATINGS :')
print(order_review_ratings.dtypes)
print('-'*125)

print('GEOLOCATION :')
print(geolocation.dtypes)
# Out:
# CUSOMER :
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
# -----------------------------------------------------------------------------------------------------------------------------
# SELLER :
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object
# -----------------------------------------------------------------------------------------------------------------------------
# PRODUCTS :
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# ...

# %%
# change the data type to date columns for orders table
orders['order_purchase_timestamp']=pd.to_datetime(orders.order_purchase_timestamp)
orders['order_approved_at']=pd.to_datetime(orders.order_approved_at)
orders['order_delivered_carrier_date']=pd.to_datetime(orders.order_delivered_carrier_date)
orders['order_delivered_customer_date']=pd.to_datetime(orders.order_delivered_customer_date)
orders['order_estimated_delivery_date']=pd.to_datetime(orders.order_estimated_delivery_date)

# change the data type to date column for order_reviews table

order_review_ratings['review_creation_date']=pd.to_datetime(order_review_ratings.review_creation_date)
order_review_ratings['review_answer_timestamp']=pd.to_datetime(order_review_ratings.review_answer_timestamp)

# change the data type to date column for order_items table
order_items['shipping_limit_date']=pd.to_datetime(order_items.shipping_limit_date)

# %%
print('CUSOMER :')
print(customers.dtypes)
print('-'*125)

print('SELLER :')
print(sellers.dtypes)
print('-'*125)

print('PRODUCTS :')
print(products.dtypes)
print('-'*125)

print('ORDERS :')
print(orders.dtypes)
print('-'*125)

print('ORDER_ITEMS :' )
print(order_items.dtypes)
print('-'*125)

print('ORDER_PAYMENTS :' )
print(order_payments.dtypes)
print('-'*125)

print('ORDER_REVIEW_RATINGS :')
print(order_review_ratings.dtypes)
print('-'*125)

print('GEOLOCATION :')
print(geolocation.dtypes)
# Out:
# CUSOMER :
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
# -----------------------------------------------------------------------------------------------------------------------------
# SELLER :
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object
# -----------------------------------------------------------------------------------------------------------------------------
# PRODUCTS :
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# ...

# %%
# create all the Joins 
# Join the customer and order data 
cust_order=pd.merge(left=customers,right=orders,left_on='customer_id',right_on='customer_id',how='left')

# Join the orders and order_payments data 
orders_join_payments=pd.merge(left=orders,right=order_payments,left_on='order_id',right_on='order_id',how='right')

# Join the orders and order_review_ratings data 
orders_join_review_ratings=pd.merge(left=orders,right=order_review_ratings,left_on='order_id',right_on='order_id',how='right')

# Join the order and order_items data 
orders_join_items=pd.merge(left=orders,right=order_items,left_on='order_id',right_on='order_id',how='right')

# Join the order_items and products data 
orders_items_join_products=pd.merge(left=order_items,right=products,left_on='product_id',right_on='product_id',how='left')

# Join the sellers and order_items data 
sellers_join_order_items=pd.merge(left=order_items,right=sellers,left_on='seller_id',right_on='seller_id',how='left')

# Join the sellers and geo_locations data 
sellers_join_geolocation=pd.merge(left=sellers,right=geolocation,left_on='seller_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='left')

# Join the customers and geo_locations data 
customers_join_geolocation=pd.merge(left=customers,right=geolocation,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='left')

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ## 1. Perform Detailed exploratory analysis

# %% [markdown]
# ### a. Define & calculate high level metrics like (Total Revenue, Total quantity, Total products, Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %%
print('Total Revenue -' ,orders_join_payments.payment_value.sum())
print('Total Quantity -',orders_join_items['order_id'].count())
print('Total products -',orders_items_join_products.product_id.nunique())
print('Total categories -', len(orders_items_join_products.product_category_name.unique()))
print('Total sellers -' , len(sellers_join_order_items.seller_id.unique()))
print ('Total Sellers locations -' , len(sellers_join_geolocation.seller_zip_code_prefix.unique()))
print ('Total Customer locations -' , len(cust_order.customer_zip_code_prefix.unique()))
print ('Total channels -' , len(orders_join_payments.payment_type.unique()))
print ('Total payment methods -' , len(orders_join_payments.payment_type.unique()))
# Out:
# Total Revenue - 16008872.12
# Total Quantity - 112650
# Total products - 32951
# Total categories - 72
# Total sellers - 3095
# Total Sellers locations - 2225
# Total Customer locations - 14994
# Total channels - 5
# Total payment methods - 5

# %% [markdown]
# ### b. Understanding how many new customers acquired every month

# %%
cust_order['month_of_year']=cust_order['order_purchase_timestamp'].apply(lambda x : pd.Timestamp.strftime(x,format='%Y-%m'))

# %%
new_cust_month_wise=cust_order.drop_duplicates(subset = ['customer_unique_id'], keep = 'first').groupby(by='month_of_year')['customer_unique_id'].nunique().reset_index()
new_cust_month_wise
# Out:
#    month_of_year  customer_unique_id
# 0        2016-09                   4
# 1        2016-10                 315
# 2        2017-01                 749
# 3        2017-02                1727
# 4        2017-03                2595
# 5        2017-04                2318
# 6        2017-05                3533
# 7        2017-06                3103
# 8        2017-07                3864
# 9        2017-08                4144
# 10       2017-09                4089
# 11       2017-10                4449
# 12       2017-11                7305
# 13       2017-12                5491
# 14       2018-01                7029
# 15       2018-02                6464
# 16       2018-03                7001
# 17       2018-04                6751
# 18       2018-05                6678
# 19       2018-06                6013
# 20       2018-07                6117
# 21       2018-08                6348
# 22       2018-09                   8
# 23       2018-10                   1

# %%
new_cust_month_wise_plot = pd.pivot_table(data = new_cust_month_wise,index=["month_of_year"],values="customer_unique_id")

# graphical representation
new_cust_month_wise_plot.plot(kind="bar",figsize=(15,8),width=.5)
plt.ylim(0, 8000)
plt.yticks(np.arange(0, 8000, step=500)) 
plt.ylabel("Number of Customers",fontsize=15)
plt.xlabel("Months of years",fontsize=15)
plt.title("New customers acquired every month",fontsize=15)
plt.show()

# %% [markdown]
# ### c. Understand the retention of customers on month on month basis

# %%
cust_monthly_count=cust_order.groupby('month_of_year')[['customer_unique_id']].count().reset_index()

# %%
cust_monthly_count.customer_unique_id.sum()
# Out:
# 99441

# %%
customers_retention=pd.merge(left=cust_monthly_count,right=new_cust_month_wise,on='month_of_year',suffixes=('_all','_new'))
customers_retention
# Out:
#    month_of_year  customer_unique_id_all  customer_unique_id_new
# 0        2016-09                       4                       4
# 1        2016-10                     324                     315
# 2        2017-01                     800                     749
# 3        2017-02                    1780                    1727
# 4        2017-03                    2682                    2595
# 5        2017-04                    2404                    2318
# 6        2017-05                    3700                    3533
# 7        2017-06                    3245                    3103
# 8        2017-07                    4026                    3864
# 9        2017-08                    4331                    4144
# 10       2017-09                    4285                    4089
# 11       2017-10                    4631                    4449
# 12       2017-11                    7544                    7305
# ...

# %%
customers_retention['customers_retained']=customers_retention.customer_unique_id_all - customers_retention.customer_unique_id_new
customers_retention
# Out:
#    month_of_year  customer_unique_id_all  customer_unique_id_new  \
# 0        2016-09                       4                       4
# 1        2016-10                     324                     315
# 2        2017-01                     800                     749
# 3        2017-02                    1780                    1727
# 4        2017-03                    2682                    2595
# 5        2017-04                    2404                    2318
# 6        2017-05                    3700                    3533
# 7        2017-06                    3245                    3103
# 8        2017-07                    4026                    3864
# 9        2017-08                    4331                    4144
# 10       2017-09                    4285                    4089
# 11       2017-10                    4631                    4449
# 12       2017-11                    7544                    7305
# ...

# %%
customers_retention['retention_rate'] = customers_retention['customers_retained']/customers_retention['customer_unique_id_all']
customers_retention
# Out:
#    month_of_year  customer_unique_id_all  customer_unique_id_new  \
# 0        2016-09                       4                       4
# 1        2016-10                     324                     315
# 2        2017-01                     800                     749
# 3        2017-02                    1780                    1727
# 4        2017-03                    2682                    2595
# 5        2017-04                    2404                    2318
# 6        2017-05                    3700                    3533
# 7        2017-06                    3245                    3103
# 8        2017-07                    4026                    3864
# 9        2017-08                    4331                    4144
# 10       2017-09                    4285                    4089
# 11       2017-10                    4631                    4449
# 12       2017-11                    7544                    7305
# ...

# %%
# graphical representation
customers_retention_plot=pd.pivot_table(data=customers_retention,index=['month_of_year'],values=['retention_rate']).reset_index()
customers_retention_plot
# Out:
#    month_of_year  retention_rate
# 0        2016-09        0.000000
# 1        2016-10        0.027778
# 2        2017-01        0.063750
# 3        2017-02        0.029775
# 4        2017-03        0.032438
# 5        2017-04        0.035774
# 6        2017-05        0.045135
# 7        2017-06        0.043760
# 8        2017-07        0.040238
# 9        2017-08        0.043177
# 10       2017-09        0.045741
# 11       2017-10        0.039300
# 12       2017-11        0.031681
# 13       2017-12        0.032082
# 14       2018-01        0.033017
# 15       2018-02        0.039239
# 16       2018-03        0.029122
# 17       2018-04        0.027093
# 18       2018-05        0.028372
# 19       2018-06        0.024972
# 20       2018-07        0.027813
# 21       2018-08        0.025184
# 22       2018-09        0.500000
# 23       2018-10        0.750000

# %%
customers_retention_plot.plot(kind= 'line', x= 'month_of_year' , y = 'retention_rate' , figsize = (20,10),marker='o')
plt.ylabel('Retention Rate %')
plt.title('Retention of customers on month on month basis')
plt.show()

# %% [markdown]
# ### d. How the revenues from existing/new customers on month on month basis

# %%
cust_order['order_purchase_year'] = cust_order.order_purchase_timestamp.dt.year
cust_order['order_purchase_month'] = cust_order.order_purchase_timestamp.dt.month

# %%
min_date_monthly = cust_order.groupby(['customer_unique_id','order_purchase_year','order_purchase_month'])['order_purchase_timestamp'].min().reset_index()
min_date_monthly
# Out:
#                      customer_unique_id  order_purchase_year  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2                 2018
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f                 2018
# 2      0000f46a3911fa3c0805444483337064                 2017
# 3      0000f6ccb0745a6a4b88665a16c9f078                 2017
# 4      0004aac84e0df4da2b147fca70cf8255                 2017
# ...                                 ...                  ...
# 98041  fffcf5a5ff07b0908bd4e2dbc735a684                 2017
# 98042  fffea47cd6d3cc0a88bd621562a9d061                 2017
# 98043  ffff371b4d645b6ecea244b27531430a                 2017
# 98044  ffff5962728ec6157033ef9805bacc48                 2018
# 98045  ffffd2657e2aad2907e67c3e9daecbeb                 2017
#
#        order_purchase_month order_purchase_timestamp
# 0                         5      2018-05-10 10:56:00
# 1                         5      2018-05-07 11:11:00
# 2                         3      2017-03-10 21:05:00
# ...

# %%
min_date_customer = cust_order.groupby('customer_unique_id')['order_purchase_timestamp'].min().reset_index()
min_date_customer
# Out:
#                      customer_unique_id order_purchase_timestamp
# 0      0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:00
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:00
# 2      0000f46a3911fa3c0805444483337064      2017-03-10 21:05:00
# 3      0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:00
# 4      0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:00
# ...                                 ...                      ...
# 96091  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:00
# 96092  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:00
# 96093  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:00
# 96094  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:00
# 96095  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:00
#
# [96096 rows x 2 columns]

# %%
cust_cat = min_date_monthly.merge(min_date_customer,on='customer_unique_id',suffixes=('_monthly','_customer'))
cust_cat
# Out:
#                      customer_unique_id  order_purchase_year  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2                 2018
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f                 2018
# 2      0000f46a3911fa3c0805444483337064                 2017
# 3      0000f6ccb0745a6a4b88665a16c9f078                 2017
# 4      0004aac84e0df4da2b147fca70cf8255                 2017
# ...                                 ...                  ...
# 98041  fffcf5a5ff07b0908bd4e2dbc735a684                 2017
# 98042  fffea47cd6d3cc0a88bd621562a9d061                 2017
# 98043  ffff371b4d645b6ecea244b27531430a                 2017
# 98044  ffff5962728ec6157033ef9805bacc48                 2018
# 98045  ffffd2657e2aad2907e67c3e9daecbeb                 2017
#
#        order_purchase_month order_purchase_timestamp_monthly  \
# 0                         5              2018-05-10 10:56:00
# 1                         5              2018-05-07 11:11:00
# ...

# %%
cust_cat['customer_category'] = 'NEW'
cust_cat.loc[cust_cat['order_purchase_timestamp_monthly'] > cust_cat['order_purchase_timestamp_customer'], 'customer_category'] = 'EXISTING'

# %%
cust_cat.customer_category.value_counts()
# Out:
# customer_category
# NEW         96096
# EXISTING     1950
# Name: count, dtype: int64

# %%
cust_cat_seg = cust_cat.loc[:,['customer_unique_id','customer_category']]
cust_cat_seg
# Out:
#                      customer_unique_id customer_category
# 0      0000366f3b9a7992bf8c76cfdf3221e2               NEW
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f               NEW
# 2      0000f46a3911fa3c0805444483337064               NEW
# 3      0000f6ccb0745a6a4b88665a16c9f078               NEW
# 4      0004aac84e0df4da2b147fca70cf8255               NEW
# ...                                 ...               ...
# 98041  fffcf5a5ff07b0908bd4e2dbc735a684               NEW
# 98042  fffea47cd6d3cc0a88bd621562a9d061               NEW
# 98043  ffff371b4d645b6ecea244b27531430a               NEW
# 98044  ffff5962728ec6157033ef9805bacc48               NEW
# 98045  ffffd2657e2aad2907e67c3e9daecbeb               NEW
#
# [98046 rows x 2 columns]

# %%
cust_orders_join_payments = pd.merge(pd.merge(cust_order,cust_cat_seg,on='customer_unique_id',how='left'),order_payments,on='order_id',how='right')
cust_orders_join_payments
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       f2c7fc58a9de810828715166c672f10a  a8b9d3a27068454b1c98cc67d4e31e6f
# 2       25b14b69de0b6e184ae6fe2755e478f9  6f70c0b2f7552832ba46eb57b1c5651e
# 3       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# 4       15fd6fb8f8312dbb4674e4518d6fa3b3  4291db0da71914754618cd789aebcd56
# ...                                  ...                               ...
# 108773  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 108774  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 108775  e4abb5057ec8cfda9759c0dc415a8188  d3c7da954a324253814096bcaf240e4e
# 108776  5d719b0d300663188169c6560e243f27  b84dc68f02f122a88d7e7bbd37b06204
# 108777  4c7f868f43b5cff577b0becb8c8b7860  b1f51a4e19da3338e51fbcfabefad1bf
#
# ...

# %%
total_monthly_revenue = cust_orders_join_payments.pivot_table(index='month_of_year',columns='customer_category',values='payment_value',aggfunc=sum)
total_monthly_revenue
# Out:
# customer_category  EXISTING         NEW
# month_of_year
# 2016-09                 NaN      252.24
# 2016-10              973.71    59090.48
# 2016-12               19.62       19.62
# 2017-01             5948.05   138488.04
# 2017-02             6752.35   291908.01
# 2017-03            20670.24   449863.60
# 2017-04            18285.38   417788.03
# 2017-05            30600.13   592918.82
# 2017-06            29205.22   511276.38
# 2017-07            33180.56   592382.92
# 2017-08            37148.96   674396.32
# 2017-09            36343.10   727762.45
# 2017-10            38157.49   779677.88
# 2017-11            50337.67  1194882.80
# 2017-12            34953.84   878401.48
# 2018-01            46957.63  1115004.18
# 2018-02            41649.13   992463.34
# 2018-03            36071.27  1159652.12
# 2018-04            46748.98  1160785.48
# 2018-05            45183.62  1153982.15
# 2018-06            40990.83  1023880.50
# 2018-07            40424.94  1066540.75
# ...

# %%
total_monthly_revenue.plot(kind='bar',figsize=(15,10))
plt.show()

# %% [markdown]
# ### e. Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, channel, payment method etc…

# %%
merged_df = pd.merge(cust_orders_join_payments,orders_items_join_products,on='order_id')

# %%
merged_df['order_week'] = merged_df.order_purchase_timestamp.dt.to_period('W')
merged_df['order_day'] = merged_df.order_purchase_timestamp.dt.day
merged_df['order_hour'] = merged_df.order_purchase_timestamp.dt.hour

# %%
merged_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       f2c7fc58a9de810828715166c672f10a  a8b9d3a27068454b1c98cc67d4e31e6f
# 2       25b14b69de0b6e184ae6fe2755e478f9  6f70c0b2f7552832ba46eb57b1c5651e
# 3       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# 4       15fd6fb8f8312dbb4674e4518d6fa3b3  4291db0da71914754618cd789aebcd56
# ...                                  ...                               ...
# 123463  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 123464  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 123465  e4abb5057ec8cfda9759c0dc415a8188  d3c7da954a324253814096bcaf240e4e
# 123466  5d719b0d300663188169c6560e243f27  b84dc68f02f122a88d7e7bbd37b06204
# 123467  4c7f868f43b5cff577b0becb8c8b7860  b1f51a4e19da3338e51fbcfabefad1bf
#
# ...

# %% [markdown]
# ####  Monthly Sales and Quantity

# %%
monthly_sales_quantity = merged_df.groupby('month_of_year').agg({'payment_value': 'sum', 'order_item_id': 'count'})
monthly_sales_quantity
# Out:
#                payment_value  order_item_id
# month_of_year
# 2016-09               347.52              3
# 2016-10             74888.29            392
# 2016-12                39.24              2
# 2017-01            196445.80           1054
# 2017-02            351289.24           2121
# 2017-03            551281.44           3317
# 2017-04            526301.67           2976
# 2017-05            763925.52           4649
# 2017-06            639366.04           4010
# 2017-07            784923.98           5150
# 2017-08            921756.06           5554
# 2017-09           1061761.76           5434
# 2017-10           1080500.12           5927
# 2017-11           1650570.89           9430
# 2017-12           1090112.98           6890
# 2018-01           1469499.80           8933
# 2018-02           1392794.40           8315
# 2018-03           1530384.01           8911
# 2018-04           1570927.77           8662
# 2018-05           1573069.50           8618
# ...

# %%
monthly_sales_quantity.plot(figsize=(12, 6), subplots=True)
plt.suptitle('Monthly Sales and Quantity')
plt.show()

# %% [markdown]
# #### Category-wise Sales and Quantity

# %%
category_sales_quantity = merged_df.groupby('product_category_name').agg({'payment_value': 'sum', 'order_item_id': 'count'})
category_sales_quantity
# Out:
#                             payment_value  order_item_id
# product_category_name
# Agro_Industry_And_Commerce      119793.30            257
# Air_Conditioning                 93301.40            314
# Art                              31407.26            222
# Arts_And_Craftmanship             2735.29             28
# Audio                            62850.69            399
# ...                                   ...            ...
# Stationery                      327045.13           2710
# Tablets_Printing_Image           10456.46             93
# Telephony                       499925.17           4900
# Toys                            646578.40           4482
# Watches_Gifts                  1496372.12           6486
#
# [71 rows x 2 columns]

# %%
category_sales_quantity.plot(kind='barh', figsize=(12, 25), stacked=True)
plt.title('Category-wise Sales and Quantity')
plt.xlabel('Product Category')
plt.ylabel('Total Sales and Quantity')
plt.show()

# %% [markdown]
# ####  Location-wise Sales (Pie Chart)

# %%
location_sales = merged_df.groupby('customer_city')['payment_value'].sum()
location_sales
# Out:
# customer_city
# Aadityana          2090.83
# Aambaliyasan        242.94
# Aantaliya         16726.52
# Aarambhada         8462.21
# Abiramam             89.19
#                     ...
# Zamin Uthukuli      221.71
# Ziauddin Pur      25909.44
# Zira                568.43
# Zirakpur            600.64
# Ziro               8216.56
# Name: payment_value, Length: 4110, dtype: float64

# %%
top_cities = location_sales.nlargest(10)
plt.figure(figsize=(6, 6))
plt.pie(top_cities, labels=top_cities.index, autopct='%1.1f%%', startangle=45)
plt.title('Top 10 Cities - Sales Distribution')
plt.show()

# %% [markdown]
# #### Day-wise Sales

# %%
day_sales = merged_df.groupby('order_day')['payment_value'].sum()
day_sales
# Out:
# order_day
# 1     735438.52
# 2     688548.81
# 3     678813.89
# 4     704336.96
# 5     765808.66
# 6     767055.58
# 7     717210.58
# 8     685391.50
# 9     694058.73
# 10    676219.60
# 11    722665.21
# 12    695654.38
# 13    702191.23
# 14    676006.55
# 15    731301.67
# 16    744909.74
# 17    661126.05
# 18    750363.50
# 19    725382.01
# 20    685570.56
# 21    594913.18
# 22    685419.78
# 23    698399.28
# 24    815546.37
# 25    689904.55
# 26    674548.86
# 27    685448.29
# 28    652647.64
# 29    637458.14
# 30    544837.60
# 31    365390.42
# Name: payment_value, dtype: float64

# %%
day_sales.plot(figsize=(12, 6))
plt.title('Day-wise Sales')
plt.xlabel('Day of the Month')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# #### Hour-wise Sales

# %%
hour_sales = merged_df.groupby('order_hour')['payment_value'].sum()
hour_sales
# Out:
# order_hour
# 0      487311.42
# 1      221248.63
# 2       97083.98
# 3       55538.56
# 4       41645.87
# 5       32555.77
# 6       91420.96
# 7      237310.56
# 8      622677.72
# 9     1152637.77
# 10    1328795.06
# 11    1355722.95
# 12    1315107.54
# 13    1362705.30
# 14    1551594.71
# 15    1556194.31
# 16    1468998.54
# 17    1316834.17
# 18    1302625.35
# 19    1216643.72
# 20    1260425.16
# 21    1237825.85
# 22    1148680.06
# 23     790983.88
# Name: payment_value, dtype: float64

# %%
hour_sales.plot(figsize=(12, 6))
plt.title('Hour-wise Sales')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# #### Payment Method-wise Sales

# %%
merged_df.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'month_of_year', 'order_purchase_year',
#        'order_purchase_month', 'customer_category', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'order_week', 'order_day',
#        'order_hour'],
#       dtype='object')

# %%
payment_method_sales = merged_df.groupby('payment_type')['payment_value'].sum()
payment_method_sales
# Out:
# payment_type
# UPI             4271847.95
# credit_card    16285440.82
# debit_card       261907.52
# voucher          433371.55
# Name: payment_value, dtype: float64

# %%
payment_method_sales.plot(kind='barh', figsize=(12, 6))
plt.title('Payment Method-wise Sales')
plt.xlabel('Payment Method')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### f. Popular Products by month, seller, state, category.

# %% [markdown]
# #### Popular Products by Category

# %%
sort_popular_Prod_by_category=merged_df.groupby('product_category_name')['order_id'].agg('count').reset_index().sort_values(by='order_id',ascending=False)
sort_popular_Prod_by_category
# Out:
#         product_category_name  order_id
# 7              Bed_Bath_Table     12631
# 43              Health_Beauty     10381
# 65             Sports_Leisure      9543
# 39            Furniture_Decor      9230
# 15      Computers_Accessories      8454
# ..                        ...       ...
# 3       Arts_And_Craftmanship        28
# 52                 La_Cuisine        18
# 11          Cds_Dvds_Musicals        14
# 29  Fashion_Childrens_Clothes         8
# 61      Security_And_Services         2
#
# [71 rows x 2 columns]

# %%
sort_popular_Prod_by_category.plot.bar(x='product_category_name',y='order_id',figsize=(15,10))
plt.show()

# %% [markdown]
# #### Popular Products by Month

# %%
popular_Prod_by_month = merged_df.groupby(['month_of_year','product_category_name'])['order_id'].agg('count').reset_index()
sort_popular_Prod_by_month = popular_Prod_by_month.sort_values(by=['month_of_year','order_id'],ascending=[True,False]).drop_duplicates(['month_of_year'])
sort_popular_Prod_by_month
# Out:
#      month_of_year                    product_category_name  order_id
# 0          2016-09                          Furniture_Decor         2
# 20         2016-10                          Furniture_Decor        75
# 33         2016-12                 Fashion_Bags_Accessories         2
# 55         2017-01                          Furniture_Decor       212
# 104        2017-02                          Furniture_Decor       293
# 154        2017-03                          Furniture_Decor       355
# 186        2017-04                           Bed_Bath_Table       317
# 245        2017-05                           Bed_Bath_Table       456
# 302        2017-06                           Bed_Bath_Table       441
# 362        2017-07                           Bed_Bath_Table       651
# 422        2017-08                           Bed_Bath_Table       659
# 485        2017-09                           Bed_Bath_Table       616
# ...

# %% [markdown]
# #### Popular Products by Seller

# %%
sellers_join_order_items_products = pd.merge(sellers_join_order_items,products,on='product_id')
populer_prod_by_seller = sellers_join_order_items_products.groupby(['seller_id','product_category_name'])['order_id'].agg('count').reset_index()
sort_populer_prod_by_seller_count = populer_prod_by_seller.sort_values(by='order_id',ascending=False).drop_duplicates('seller_id').reset_index(drop=True)
sort_populer_prod_by_seller_count
# Out:
#                              seller_id product_category_name  order_id
# 0     1f50f920176fa81dab994f9023523100          Garden_Tools      1882
# 1     6560211a19b47992c3666cc44a7e94c0         Watches_Gifts      1628
# 2     4a3ca9315b744ce9f8e9374361493884        Bed_Bath_Table      1572
# 3     1025f0e2d44d7041d6cf58b6550e0bfa       Furniture_Decor      1292
# 4     da8622b14eb17ae2831f4ac5b9dab84a        Bed_Bath_Table      1277
# ...                                ...                   ...       ...
# 3028  86649b1632b1c0e6c0bcb2c90a8b75d8         Health_Beauty         1
# 3029  87b4428a334b8f676fd9a7f3bf544fb5         Health_Beauty         1
# 3030  820c7c9eaf76d2b226b6c242bcf3f34d     Home_Appliances_2         1
# 3031  82921991ff5b557b045605b8bbf08d49             Telephony         1
# 3032  83d458c0d6d4f94295d63f091460bd60                  Toys         1
#
# [3033 rows x 3 columns]

# %%
populer_prod_by_state_count = sellers_join_order_items_products.groupby(['seller_state','product_category_name'])['order_id'].agg('count').reset_index()
sort_populer_prod_by_state_count = populer_prod_by_state_count.sort_values(by='order_id',ascending=False).drop_duplicates('seller_state').reset_index(drop=True)
sort_populer_prod_by_state_count
# Out:
#          seller_state            product_category_name  order_id
# 0      Andhra Pradesh                    Health_Beauty      7639
# 1             Gujarat                   Bed_Bath_Table      6312
# 2        Chhattisgarh                       Housewares       664
# 3             Haryana            Computers_Accessories       534
# 4           Karnataka                  Furniture_Decor       505
# 5         West Bengal                     Garden_Tools       425
# 6     Jammu & Kashmir                   Sports_Leisure       409
# 7   Arunachal Pradesh                   Sports_Leisure       400
# 8      Madhya Pradesh                   Sports_Leisure       343
# 9               Delhi                    Health_Beauty       279
# 10          Rajasthan              Luggage_Accessories       273
# 11        Maharashtra                             Toys       201
# 12   Himachal Pradesh                   Sports_Leisure       161
# ...

# %% [markdown]
# ### g. Popular categories by state, month

# %% [markdown]
# #### Popular Categories by Month

# %%
merged_df['order_month'] = merged_df.order_purchase_timestamp.dt.month
Popular_category_by_month = merged_df.groupby(['order_month','product_category_name'])['order_id'].agg('count').reset_index()
sort_Popular_category_by_month = Popular_category_by_month.sort_values(by=['order_month','order_id'],ascending=(True,False)).drop_duplicates('order_month').reset_index(drop=True)
sort_Popular_category_by_month
# Out:
#     order_month  product_category_name  order_id
# 0             1         Bed_Bath_Table      1011
# 1             2  Computers_Accessories      1145
# 2             3         Bed_Bath_Table      1223
# 3             4         Bed_Bath_Table      1151
# 4             5         Bed_Bath_Table      1286
# 5             6         Bed_Bath_Table      1333
# 6             7         Bed_Bath_Table      1322
# 7             8         Bed_Bath_Table      1363
# 8             9         Bed_Bath_Table       616
# 9            10         Bed_Bath_Table       653
# 10           11         Bed_Bath_Table      1091
# 11           12         Bed_Bath_Table       626

# %%
Popular_category_by_state = merged_df.groupby(['customer_state','product_category_name'])['order_id'].agg('count').reset_index()
sort_Popular_category_by_state = Popular_category_by_state.sort_values(by='order_id',ascending=False).drop_duplicates('customer_state').reset_index(drop=True)
sort_Popular_category_by_state
# Out:
#        customer_state product_category_name  order_id
# 0      Andhra Pradesh        Bed_Bath_Table      8157
# 1             Gujarat        Bed_Bath_Table       847
# 2        Chhattisgarh        Bed_Bath_Table       780
# 3           Karnataka        Bed_Bath_Table       427
# 4      Madhya Pradesh        Bed_Bath_Table       356
# 5               Delhi         Health_Beauty       349
# 6             Haryana        Bed_Bath_Table       327
# 7          Tamil Nadu        Bed_Bath_Table       233
# 8         Maharashtra        Bed_Bath_Table       233
# 9     Jammu & Kashmir        Bed_Bath_Table       189
# 10             Kerala        Bed_Bath_Table       159
# 11  Arunachal Pradesh        Bed_Bath_Table       135
# 12      Uttar Pradesh         Health_Beauty       115
# 13          Rajasthan        Sports_Leisure       106
# 14   Himachal Pradesh        Bed_Bath_Table        91
# 15             Orissa        Bed_Bath_Table        85
# ...

# %% [markdown]
# ### h. List top 10 most expensive products sorted by price

# %%
most_exp_top_10_prod = orders_items_join_products.groupby('product_category_name')['price'].max().reset_index().sort_values('price',ascending=False).nlargest(10,'price').reset_index(drop=True)
most_exp_top_10_prod
# Out:
#   product_category_name    price
# 0            Housewares  6735.00
# 1             Computers  6729.00
# 2                   Art  6499.00
# 3      Small_Appliances  4799.00
# 4   Musical_Instruments  4399.87
# 5        Consoles_Games  4099.99
# 6        Sports_Leisure  4059.00
# 7         Watches_Gifts  3999.90
# 8          Garden_Tools  3930.00
# 9                  Baby  3899.00

# %%
most_exp_top_10_prod.plot.bar(x='product_category_name',y='price',figsize=(20,10))
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ## 2. Performing Customers/sellers Segmentation

# %% [markdown]
#   ### a. Divide the customers into groups based on the revenue generated

# %%
total_revenue_per_cust = cust_orders_join_payments.groupby('customer_unique_id')['payment_value'].sum().reset_index()
total_revenue_per_cust
# Out:
#                      customer_unique_id  payment_value
# 0      0000366f3b9a7992bf8c76cfdf3221e2         141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          27.19
# 2      0000f46a3911fa3c0805444483337064          86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078          43.62
# 4      0004aac84e0df4da2b147fca70cf8255         196.89
# ...                                 ...            ...
# 96090  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42
# 96091  fffea47cd6d3cc0a88bd621562a9d061          84.58
# 96092  ffff371b4d645b6ecea244b27531430a         112.46
# 96093  ffff5962728ec6157033ef9805bacc48         133.69
# 96094  ffffd2657e2aad2907e67c3e9daecbeb          71.56
#
# [96095 rows x 2 columns]

# %%
print(cust_orders_join_payments.payment_value.min())
print(cust_orders_join_payments.payment_value.max())
print(cust_orders_join_payments.payment_value.mean())
# Out:
# 0.0
# 13664.08
# 153.44254518376874

# %%
total_revenue_per_cust['customer_segment'] = total_revenue_per_cust.payment_value.apply(lambda x : 'high budget' if x>1000 else 'mid budget' if x>500 else 'low budget' if x>1 else 'zero spend')
total_revenue_per_cust
# Out:
#                      customer_unique_id  payment_value customer_segment
# 0      0000366f3b9a7992bf8c76cfdf3221e2         141.90       low budget
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          27.19       low budget
# 2      0000f46a3911fa3c0805444483337064          86.22       low budget
# 3      0000f6ccb0745a6a4b88665a16c9f078          43.62       low budget
# 4      0004aac84e0df4da2b147fca70cf8255         196.89       low budget
# ...                                 ...            ...              ...
# 96090  fffcf5a5ff07b0908bd4e2dbc735a684        2067.42      high budget
# 96091  fffea47cd6d3cc0a88bd621562a9d061          84.58       low budget
# 96092  ffff371b4d645b6ecea244b27531430a         112.46       low budget
# 96093  ffff5962728ec6157033ef9805bacc48         133.69       low budget
# 96094  ffffd2657e2aad2907e67c3e9daecbeb          71.56       low budget
#
# [96095 rows x 3 columns]

# %%
total_revenue_per_cust.drop(columns = 'payment_value',inplace=True)
total_revenue_per_cust
# Out:
#                      customer_unique_id customer_segment
# 0      0000366f3b9a7992bf8c76cfdf3221e2       low budget
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f       low budget
# 2      0000f46a3911fa3c0805444483337064       low budget
# 3      0000f6ccb0745a6a4b88665a16c9f078       low budget
# 4      0004aac84e0df4da2b147fca70cf8255       low budget
# ...                                 ...              ...
# 96090  fffcf5a5ff07b0908bd4e2dbc735a684      high budget
# 96091  fffea47cd6d3cc0a88bd621562a9d061       low budget
# 96092  ffff371b4d645b6ecea244b27531430a       low budget
# 96093  ffff5962728ec6157033ef9805bacc48       low budget
# 96094  ffffd2657e2aad2907e67c3e9daecbeb       low budget
#
# [96095 rows x 2 columns]

# %%
cust_orders_join_payments = pd.merge(cust_orders_join_payments,total_revenue_per_cust,on='customer_unique_id')
cust_orders_join_payments
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       f2c7fc58a9de810828715166c672f10a  a8b9d3a27068454b1c98cc67d4e31e6f
# 2       25b14b69de0b6e184ae6fe2755e478f9  6f70c0b2f7552832ba46eb57b1c5651e
# 3       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# 4       15fd6fb8f8312dbb4674e4518d6fa3b3  4291db0da71914754618cd789aebcd56
# ...                                  ...                               ...
# 108773  d8f3aacf5cf5ddf9ceef4ad39e874c98  0858c8086ef3b4bc86fef82638bcfa52
# 108774  5d576cb2dfa3bc05612c392a1ee9c654  b6027ac07fb76ebca8c97b1887865aee
# 108775  e4abb5057ec8cfda9759c0dc415a8188  d3c7da954a324253814096bcaf240e4e
# 108776  5d719b0d300663188169c6560e243f27  b84dc68f02f122a88d7e7bbd37b06204
# 108777  4c7f868f43b5cff577b0becb8c8b7860  b1f51a4e19da3338e51fbcfabefad1bf
#
# ...

# %%
cust_segment_by_sepend = cust_orders_join_payments.groupby('customer_segment')['customer_unique_id'].count()
cust_segment_by_sepend
# Out:
# customer_segment
# high budget     3422
# low budget     99208
# mid budget      6146
# zero spend         2
# Name: customer_unique_id, dtype: int64

# %%
cust_segment_by_sepend.plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### b. Divide the sellers into groups based on the revenue generated

# %%
revene_per_seller = pd.merge(merged_df,sellers,on='seller_id',how='left')
revene_per_seller
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       f2c7fc58a9de810828715166c672f10a  a8b9d3a27068454b1c98cc67d4e31e6f
# 2       25b14b69de0b6e184ae6fe2755e478f9  6f70c0b2f7552832ba46eb57b1c5651e
# 3       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# 4       15fd6fb8f8312dbb4674e4518d6fa3b3  4291db0da71914754618cd789aebcd56
# ...                                  ...                               ...
# 123463  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 123464  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 123465  e4abb5057ec8cfda9759c0dc415a8188  d3c7da954a324253814096bcaf240e4e
# 123466  5d719b0d300663188169c6560e243f27  b84dc68f02f122a88d7e7bbd37b06204
# 123467  4c7f868f43b5cff577b0becb8c8b7860  b1f51a4e19da3338e51fbcfabefad1bf
#
# ...

# %%
populer_prod_by_seller = revene_per_seller.groupby('seller_id')['payment_value'].sum().reset_index()
populer_prod_by_seller
# Out:
#                              seller_id  payment_value
# 0     0015a82c2db000af6aaaf3ae2ecb0532        2748.06
# 1     001cca7ae9ae17fb1caed9dfb1094831       48962.29
# 2     001e6ad469a905060d959994f1b41e4f         267.94
# 3     002100f778ceb8431b7a1020ff7ab48f        2508.08
# 4     003554e2dce176b5555353e4f3555ac8         139.38
# ...                                ...            ...
# 3090  ffcfefa19b08742c5d315f2791395ee5          79.52
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3        3970.03
# 3092  ffeee66ac5d5a62fe688b9d26f83f534        2259.55
# 3093  fffd5413c0700ac820c7069d66d98c89       13848.17
# 3094  ffff564a4f9085cd26170f4732393726        1801.03
#
# [3095 rows x 2 columns]

# %%
print(populer_prod_by_seller.payment_value.min())
print(populer_prod_by_seller.payment_value.max())
print(populer_prod_by_seller.payment_value.mean())
# Out:
# 12.22
# 539560.8
# 6866.742436187399

# %%
populer_prod_by_seller['seller_segment'] = populer_prod_by_seller.payment_value.apply(lambda x : 'Top seller' if x>200000 else 'Best seller' if x>100000 else 'Good seller' if x>50000 else 'Poor seller' if x>20000 else 'Worst seller')
populer_prod_by_seller
# Out:
#                              seller_id  payment_value seller_segment
# 0     0015a82c2db000af6aaaf3ae2ecb0532        2748.06   Worst seller
# 1     001cca7ae9ae17fb1caed9dfb1094831       48962.29    Poor seller
# 2     001e6ad469a905060d959994f1b41e4f         267.94   Worst seller
# 3     002100f778ceb8431b7a1020ff7ab48f        2508.08   Worst seller
# 4     003554e2dce176b5555353e4f3555ac8         139.38   Worst seller
# ...                                ...            ...            ...
# 3090  ffcfefa19b08742c5d315f2791395ee5          79.52   Worst seller
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3        3970.03   Worst seller
# 3092  ffeee66ac5d5a62fe688b9d26f83f534        2259.55   Worst seller
# 3093  fffd5413c0700ac820c7069d66d98c89       13848.17   Worst seller
# 3094  ffff564a4f9085cd26170f4732393726        1801.03   Worst seller
#
# [3095 rows x 3 columns]

# %%
populer_prod_by_seller.drop(columns='payment_value',inplace=True)
populer_prod_by_seller
# Out:
#                              seller_id seller_segment
# 0     0015a82c2db000af6aaaf3ae2ecb0532   Worst seller
# 1     001cca7ae9ae17fb1caed9dfb1094831    Poor seller
# 2     001e6ad469a905060d959994f1b41e4f   Worst seller
# 3     002100f778ceb8431b7a1020ff7ab48f   Worst seller
# 4     003554e2dce176b5555353e4f3555ac8   Worst seller
# ...                                ...            ...
# 3090  ffcfefa19b08742c5d315f2791395ee5   Worst seller
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3   Worst seller
# 3092  ffeee66ac5d5a62fe688b9d26f83f534   Worst seller
# 3093  fffd5413c0700ac820c7069d66d98c89   Worst seller
# 3094  ffff564a4f9085cd26170f4732393726   Worst seller
#
# [3095 rows x 2 columns]

# %%
revene_per_seller = pd.merge(revene_per_seller,populer_prod_by_seller,on='seller_id')
revene_per_seller
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       3aec6e3846fd122ac430ac1a816107a8  74fe4e106702770ef728399ce5da503a
# 2       3aec6e3846fd122ac430ac1a816107a8  74fe4e106702770ef728399ce5da503a
# 3       3aec6e3846fd122ac430ac1a816107a8  74fe4e106702770ef728399ce5da503a
# 4       3aec6e3846fd122ac430ac1a816107a8  74fe4e106702770ef728399ce5da503a
# ...                                  ...                               ...
# 123463  5382e619221117fc8021550996a4e417  b8b32554df7a612f3aefb40b44653a4d
# 123464  566eb70d22f8c4b3ebd3b2db8718ff7d  df35c187eb00e0b6670f8c8fc252b7f8
# 123465  0b62558584ba5942cb07377647332e23  c9aa33473ec2343d8a2a0b11ebd36b1d
# 123466  3f27a4fd3d61f939a07a45a389c6d0c7  0311deb2e956cb6966ec4773130ba658
# 123467  3f27a4fd3d61f939a07a45a389c6d0c7  0311deb2e956cb6966ec4773130ba658
#
#         customer_zip_code_prefix   customer_city  customer_state  \
# ...

# %%
seller_count_by_segment = revene_per_seller.groupby('seller_segment')['seller_id'].count()
seller_count_by_segment
# Out:
# seller_segment
# Best seller     11557
# Good seller     18967
# Poor seller     22880
# Top seller      12993
# Worst seller    57071
# Name: seller_id, dtype: int64

# %%
seller_count_by_segment.plot.bar()
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 3. Cross-Selling (Which products are selling together)
# #### Hint: We need to find which of the top 10 combinations of products are selling together in each transaction. (combination of 2 or 3 buying together)

# %%
from itertools import combinations
from collections import Counter

# %%
items = orders_items_join_products[orders_items_join_products.order_id.duplicated(keep=False)]
items
# Out:
#                                 order_id  order_item_id  \
# 13      0008288aa423d2a3f00fcb17cd7d8719              1
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 32      00143d0f86d6fbd9f9b38ab440ac16f5              1
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# ...                                  ...            ...
# 112635  fff8287bbae429a99bb7e8c21d151c41              2
# 112640  fffb9224b6fc7c43ebb0904318b10b5f              1
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 13      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# ...

# %%
order_product_groups = items.groupby('order_id')['product_category_name'].agg(list).reset_index()

product_combinations = []

for product in order_product_groups.product_category_name:
    for comb in combinations(product,2):
        if len(set(comb)) == len(comb):
            product_combinations.append(comb)
    for comb in combinations(product,3):
        if len(set(comb)) == len(comb):
            product_combinations.append(comb)

product_combinations_count = Counter(product_combinations)

top_10_combinations = product_combinations_count.most_common(10)

print("Top 10 combinations of products sold together:")
for combination, count in top_10_combinations:
    print(f"Combination: {combination}, Count: {count}")
# Out:
# Top 10 combinations of products sold together:
# Combination: ('Furniture_Decor', 'Bed_Bath_Table'), Count: 66
# Combination: ('Bed_Bath_Table', 'Furniture_Decor'), Count: 62
# Combination: ('Furniture_Decor', 'Garden_Tools'), Count: 35
# Combination: ('Home_Confort', 'Bed_Bath_Table'), Count: 33
# Combination: ('Garden_Tools', 'Furniture_Decor'), Count: 25
# Combination: ('Bed_Bath_Table', 'Home_Confort'), Count: 25
# Combination: ('Bed_Bath_Table', 'Housewares'), Count: 20
# Combination: (nan, 'Computers_Accessories'), Count: 20
# Combination: ('Housewares', 'Furniture_Decor'), Count: 19
# Combination: ('Furniture_Decor', 'Housewares'), Count: 18

# %% [markdown]
# ## 4. Payment Behaviour

# %% [markdown]
# ### a. How customers are paying?

# %%
cust_payment_pattern=orders_join_payments.groupby('payment_installments')[['customer_id']].count()
cust_payment_pattern
# Out:
#                       customer_id
# payment_installments
# 0                               2
# 1                           52546
# 2                           12413
# 3                           10461
# 4                            7098
# 5                            5239
# 6                            3920
# 7                            1626
# 8                            4268
# 9                             644
# 10                           5328
# 11                             23
# 12                            133
# 13                             16
# 14                             15
# 15                             74
# 16                              5
# 17                              8
# 18                             27
# 20                             17
# 21                              3
# 22                              1
# 23                              1
# 24                             18

# %%
cust_payment_pattern.plot.bar(figsize=(12,6))
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### b. Which payment channels are used by most customers?

# %%
most_used_payment_channels=orders_join_payments.groupby('payment_type')[['customer_id']].count().sort_values(by='customer_id')
most_used_payment_channels
# Out:
#               customer_id
# payment_type
# not_defined             3
# debit_card           1529
# voucher              5775
# UPI                 19784
# credit_card         76795

# %%
most_used_payment_channels.plot.bar(figsize=(12,6))
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ## 5. Customer satisfaction towards category & product

# %% [markdown]
# ### a. Which categories (top 10) are maximum rated & minimum rated?

# %%
prod_and_cat=orders_items_join_products[['order_id','product_category_name']]
prod_and_cat
# Out:
#                                 order_id  product_category_name
# 0       00010242fe8c5a6d1ba2dd792cb16214             Cool_Stuff
# 1       00018f77f2f0320c557190d7a144bdd3               Pet_Shop
# 2       000229ec398224ef6ca0657da4fc703e        Furniture_Decor
# 3       00024acbcdf0a6daa1e931b038114c75              Perfumery
# 4       00042b26cf59d7ce69dfabb4e55b4fd9           Garden_Tools
# ...                                  ...                    ...
# 112645  fffc94f6ce00a00581880bf54a75a037             Housewares
# 112646  fffcd46ef2263f404302a634eb57f7eb  Computers_Accessories
# 112647  fffce4705a9662cd70adb13d4a31832d         Sports_Leisure
# 112648  fffe18544ffabc95dfada21779c9644f  Computers_Accessories
# 112649  fffe41c64501cc87c801fd61db3f6244         Bed_Bath_Table
#
# [112650 rows x 2 columns]

# %%
prod_cat_review_rating=orders_join_review_ratings[['order_id','review_score']]
prod_cat_review_rating
# Out:
#                                order_id  review_score
# 0      73fc7af87114b39712e6da79b0a377eb             4
# 1      a548910a1c6147796b98fdf73dbeba33             5
# 2      f9e4b658b201a9f2ecdecbb34bed034b             5
# 3      658677c97b385a9be170737859d3511b             5
# 4      8e6bfb81e283fa7e4f11123a3fb894f1             5
# ...                                 ...           ...
# 99995  22ec9f0669f784db00fa86d035cf8602             5
# 99996  55d4004744368f5571d1f590031933e4             5
# 99997  7725825d039fc1f0ceb7635e3f7d9206             4
# 99998  f8bd3f2000c28c5342fedeb5e50f2e75             1
# 99999  90531360ecb1eec2a1fbb265a0db0508             1
#
# [100000 rows x 2 columns]

# %%
prod_cat_review_rating_prod_and_cat=pd.merge(left=prod_cat_review_rating,right=prod_and_cat,left_on='order_id',right_on='order_id' , how='left')
prod_cat_review_rating_prod_and_cat
# Out:
#                                 order_id  review_score  product_category_name
# 0       73fc7af87114b39712e6da79b0a377eb             4         Sports_Leisure
# 1       73fc7af87114b39712e6da79b0a377eb             4         Sports_Leisure
# 2       a548910a1c6147796b98fdf73dbeba33             5  Computers_Accessories
# 3       f9e4b658b201a9f2ecdecbb34bed034b             5  Computers_Accessories
# 4       658677c97b385a9be170737859d3511b             5           Garden_Tools
# ...                                  ...           ...                    ...
# 114095  22ec9f0669f784db00fa86d035cf8602             5                   Toys
# 114096  55d4004744368f5571d1f590031933e4             5             Stationery
# 114097  7725825d039fc1f0ceb7635e3f7d9206             4         Sports_Leisure
# 114098  f8bd3f2000c28c5342fedeb5e50f2e75             1                   Auto
# 114099  90531360ecb1eec2a1fbb265a0db0508             1  Computers_Accessories
#
# [114100 rows x 3 columns]

# %%
category_avg_ratings = prod_cat_review_rating_prod_and_cat.groupby('product_category_name')['review_score'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
category_avg_ratings.head(10).plot(kind='bar', color='green')
plt.title('Top 10 Maximum Rated Categories')
plt.xlabel('Product Category')
plt.ylabel('Average Review Score')
plt.show()

plt.figure(figsize=(10, 5))
category_avg_ratings.tail(10).plot(kind='bar', color='red')
plt.title('Top 10 Minimum Rated Categories')
plt.xlabel('Product Category')
plt.ylabel('Average Review Score')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### b. Which products (top10) are maximum rated & minimum rated?

# %%
product_avg_ratings = prod_cat_review_rating_prod_and_cat.groupby('product_category_name')['review_score'].mean().sort_values(ascending=False)

# %%
# Top 10 Maximum Rated Products
product_avg_ratings.head(10)
# Out:
# product_category_name
# Cds_Dvds_Musicals                        4.642857
# Fashion_Childrens_Clothes                4.500000
# Books_General_Interest                   4.439421
# Books_Imported                           4.400000
# Costruction_Tools_Tools                  4.359223
# Books_Technical                          4.338290
# Luggage_Accessories                      4.309524
# Food_Drink                               4.303571
# Small_Appliances_Home_Oven_And_Coffee    4.302632
# Fashion_Sport                            4.258065
# Name: review_score, dtype: float64

# %%
# Top 10 Minimum Rated Products
product_avg_ratings.nsmallest(10)
# Out:
# product_category_name
# Security_And_Services     2.500000
# Diapers_And_Hygiene       3.256410
# Home_Comfort_2            3.366667
# Office_Furniture          3.484421
# Fashion_Male_Clothing     3.621212
# Fixed_Telephony           3.671698
# Party_Supplies            3.767442
# Fashio_Female_Clothing    3.780000
# La_Cuisine                3.785714
# Audio                     3.808219
# Name: review_score, dtype: float64

# %% [markdown]
# ### c. Average rating by location, seller, product, category, month etc.

# %%
merged_df = pd.merge(merged_df,order_review_ratings,on='order_id',how='left')
merged_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       0a8556ac6be836b46b3e89920d59291c  708ab75d2a007f0564aedd11139c7708
# 1       f2c7fc58a9de810828715166c672f10a  a8b9d3a27068454b1c98cc67d4e31e6f
# 2       25b14b69de0b6e184ae6fe2755e478f9  6f70c0b2f7552832ba46eb57b1c5651e
# 3       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# 4       7a5d8efaaa1081f800628c30d2b0728f  87695ed086ebd36f20404c82d20fca87
# ...                                  ...                               ...
# 124255  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 124256  2079230c765a88530822a34a4cec2aa0  53b30ca78efb2b7efcd3f9e461587eb2
# 124257  e4abb5057ec8cfda9759c0dc415a8188  d3c7da954a324253814096bcaf240e4e
# 124258  5d719b0d300663188169c6560e243f27  b84dc68f02f122a88d7e7bbd37b06204
# 124259  4c7f868f43b5cff577b0becb8c8b7860  b1f51a4e19da3338e51fbcfabefad1bf
#
#         customer_zip_code_prefix customer_city     customer_state  \
# ...

# %% [markdown]
# #### Average rating by location

# %%
cust_avg_rating_by_loc=merged_df.groupby(by='customer_state')[['review_score']].mean().round(2).reset_index()
cust_avg_rating_by_loc
# Out:
#        customer_state  review_score
# 0      Andhra Pradesh          4.01
# 1   Arunachal Pradesh          4.02
# 2        Chhattisgarh          4.04
# 3               Delhi          4.04
# 4                 Goa          4.80
# 5             Gujarat          4.05
# 6             Haryana          4.11
# 7    Himachal Pradesh          4.01
# 8     Jammu & Kashmir          4.00
# 9           Karnataka          4.02
# 10             Kerala          4.05
# 11     Madhya Pradesh          4.00
# 12        Maharashtra          4.10
# 13             Orissa          4.10
# 14             Punjab          4.18
# 15          Rajasthan          4.10
# 16         Tamil Nadu          4.12
# 17      Uttar Pradesh          4.13
# 18        Uttaranchal          3.72
# 19        West Bengal          4.02

# %%
cust_avg_rating_by_loc.plot.barh(x='customer_state',y='review_score',figsize=(10,10))
plt.show()

# %% [markdown]
# #### Average rating by product or category

# %%
cust_avg_rating_by_product_cat=merged_df.groupby(by='product_category_name')[['review_score']].mean().round(2).reset_index()
cust_avg_rating_by_product_cat
# Out:
#          product_category_name  review_score
# 0   Agro_Industry_And_Commerce          4.17
# 1             Air_Conditioning          3.94
# 2                          Art          3.93
# 3        Arts_And_Craftmanship          4.25
# 4                        Audio          3.82
# ..                         ...           ...
# 66                  Stationery          4.18
# 67      Tablets_Printing_Image          4.03
# 68                   Telephony          3.95
# 69                        Toys          4.15
# 70               Watches_Gifts          4.00
#
# [71 rows x 2 columns]

# %%
cust_avg_rating_by_product_cat.plot.barh(x='product_category_name',y='review_score',figsize=(10,25))
plt.show()

# %% [markdown]
# #### Average rating by Month

# %%
cust_avg_rating_by_month=merged_df.groupby(by='month_of_year')[['review_score']].mean().round(2).reset_index()
cust_avg_rating_by_month
# Out:
#    month_of_year  review_score
# 0        2016-09          1.00
# 1        2016-10          3.62
# 2        2016-12          5.00
# 3        2017-01          4.09
# 4        2017-02          4.04
# 5        2017-03          4.06
# 6        2017-04          3.96
# 7        2017-05          4.13
# 8        2017-06          4.13
# 9        2017-07          4.13
# 10       2017-08          4.22
# 11       2017-09          4.13
# 12       2017-10          4.06
# 13       2017-11          3.84
# 14       2017-12          3.93
# 15       2018-01          3.93
# 16       2018-02          3.72
# 17       2018-03          3.69
# 18       2018-04          4.07
# 19       2018-05          4.13
# 20       2018-06          4.19
# 21       2018-07          4.21
# 22       2018-08          4.21
# 23       2018-09          1.00

# %%
cust_avg_rating_by_month.plot.bar(x='month_of_year',y='review_score',figsize=(10,8))
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### Average rating by seller

# %%
seller_rating_score_by_location = pd.merge(sellers_join_order_items,prod_cat_review_rating,on='order_id')
seller_rating_score_by_location
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 113317  fffc94f6ce00a00581880bf54a75a037              1
# 113318  fffcd46ef2263f404302a634eb57f7eb              1
# 113319  fffce4705a9662cd70adb13d4a31832d              1
# 113320  fffe18544ffabc95dfada21779c9644f              1
# 113321  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
seller_average_rating_score_by_location=seller_rating_score_by_location.groupby(by='seller_state')[['review_score']].mean().round(2).reset_index()
seller_average_rating_score_by_location
# Out:
#          seller_state  review_score
# 0      Andhra Pradesh          4.02
# 1   Arunachal Pradesh          4.15
# 2        Chhattisgarh          4.11
# 3               Delhi          3.88
# 4             Gujarat          3.94
# 5             Haryana          4.07
# 6    Himachal Pradesh          4.15
# 7     Jammu & Kashmir          4.04
# 8           Karnataka          4.03
# 9              Kerala          4.24
# 10     Madhya Pradesh          4.03
# 11        Maharashtra          4.00
# 12             Orissa          4.23
# 13             Punjab          3.52
# 14          Rajasthan          4.04
# 15         Tamil Nadu          3.85
# 16      Uttar Pradesh          3.66
# 17        Uttaranchal          4.52
# 18        West Bengal          4.19

# %%
seller_average_rating_score_by_location.plot.barh(x='seller_state',y='review_score',figsize=(8,8))
plt.show()

# %% [markdown]
# ### sourabhasekharrout@gmail.com
